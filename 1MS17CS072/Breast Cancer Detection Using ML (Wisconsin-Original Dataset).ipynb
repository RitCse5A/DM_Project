# %% [markdown]
# # Importing Modules
# importing different modules used in this project for Data Analysis and Prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading Wisconsin Dataset

# %%
names=["ID","Clump_Thickness","Uniform_cell_size","Uniform_cell_shape","Marginal_Adhesion","Single_epithelial_cell_size",
      "Bare_Nuclei","Bland_Chromatin","Normal_Nucleoli","Mitoses","Class"]
df=pd.read_csv("E:/DMdataset/breast-cancer-wisconsin.data",names=names)
df
# Out:
#           ID  Clump_Thickness  Uniform_cell_size  Uniform_cell_shape  \
# 0    1000025                5                  1                   1
# 1    1002945                5                  4                   4
# 2    1015425                3                  1                   1
# 3    1016277                6                  8                   8
# 4    1017023                4                  1                   1
# ..       ...              ...                ...                 ...
# 694   776715                3                  1                   1
# 695   841769                2                  1                   1
# 696   888820                5                 10                  10
# 697   897471                4                  8                   6
# 698   897471                4                  8                   8
#
#      Marginal_Adhesion  Single_epithelial_cell_size Bare_Nuclei  \
# 0                    1                            2           1
# 1                    5                            7          10
# 2                    1                            2           2
# 3                    1                            3           4
# 4                    3                            2           1
# ..                 ...                          ...         ...
# 694                  1                            3           2
# 695                  1                            2           1
# 696                  3                            7           3
# 697                  4                            3           4
# 698                  5                            4           5
#
#      Bland_Chromatin  Normal_Nucleoli  Mitoses  Class
# 0                  3                1        1      2
# 1                  3                2        1      2
# 2                  3                1        1      2
# 3                  3                7        1      2
# 4                  3                1        1      2
# ..               ...              ...      ...    ...
# 694                1                1        1      2
# 695                1                1        1      2
# 696                8               10        2      4
# 697               10                6        1      4
# 698               10                4        1      4
#
# [699 rows x 11 columns]

# %%
# Class: (2 for benign, 4 for malignant)

# %% [markdown]
# # Data Insight
# Exploring Data for more information

# %%
print("Total Number of Rows in Dataset:",df.shape[0])
print("Total Number of Columns in Dataset:",df.shape[1])
# Out:
# Total Number of Rows in Dataset: 699
# Total Number of Columns in Dataset: 11
# size (699, 11)

# %%
for i,col in enumerate(df.columns):
    print(i+1,"Column is ",col)
# Out:
# 1 Column is  ID
# 2 Column is  Clump_Thickness
# 3 Column is  Uniform_cell_size
# 4 Column is  Uniform_cell_shape
# 5 Column is  Marginal_Adhesion
# 6 Column is  Single_epithelial_cell_size
# 7 Column is  Bare_Nuclei
# 8 Column is  Bland_Chromatin
# 9 Column is  Normal_Nucleoli
# 10 Column is  Mitoses
# 11 Column is  Class

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
# ID                             699 non-null int64
# Clump_Thickness                699 non-null int64
# Uniform_cell_size              699 non-null int64
# Uniform_cell_shape             699 non-null int64
# Marginal_Adhesion              699 non-null int64
# Single_epithelial_cell_size    699 non-null int64
# Bare_Nuclei                    699 non-null object
# Bland_Chromatin                699 non-null int64
# Normal_Nucleoli                699 non-null int64
# Mitoses                        699 non-null int64
# Class                          699 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
df.describe()
# Out:
#                  ID  Clump_Thickness  Uniform_cell_size  Uniform_cell_shape  \
# count  6.990000e+02       699.000000         699.000000          699.000000
# mean   1.071704e+06         4.417740           3.134478            3.207439
# std    6.170957e+05         2.815741           3.051459            2.971913
# min    6.163400e+04         1.000000           1.000000            1.000000
# 25%    8.706885e+05         2.000000           1.000000            1.000000
# 50%    1.171710e+06         4.000000           1.000000            1.000000
# 75%    1.238298e+06         6.000000           5.000000            5.000000
# max    1.345435e+07        10.000000          10.000000           10.000000
#
#        Marginal_Adhesion  Single_epithelial_cell_size  Bland_Chromatin  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     2.000000         2.000000
# 50%             1.000000                     2.000000         3.000000
# 75%             4.000000                     4.000000         5.000000
# max            10.000000                    10.000000        10.000000
#
#        Normal_Nucleoli     Mitoses       Class
# count       699.000000  699.000000  699.000000
# mean          2.866953    1.589413    2.689557
# std           3.053634    1.715078    0.951273
# min           1.000000    1.000000    2.000000
# 25%           1.000000    1.000000    2.000000
# 50%           1.000000    1.000000    2.000000
# 75%           4.000000    1.000000    4.000000
# max          10.000000   10.000000    4.000000

# %% [markdown]
# # Data Visualization

# %%
# Histograms

df.hist(figsize=(20,20))
plt.show()

# %%
# Scatter plot Clump Thickness vs other Parameter
fig=plt.subplots(figsize=(15,20))
features=['Clump_Thickness', 'Uniform_cell_size', 'Uniform_cell_shape', 'Marginal_Adhesion', 'Single_epithelial_cell_size', 'Bare_Nuclei', 'Bland_Chromatin', 'Normal_Nucleoli', 'Mitoses']
for i,j in enumerate(features):
    plt.subplots_adjust(hspace = 1.0)
    plt.subplot(4, 3, i+1)
    sns.scatterplot("Clump_Thickness",y=j,data=df)

# %%
# Scatter plot Cell_Size vs other Parameter
fig=plt.subplots(figsize=(15,20))
features=['Clump_Thickness', 'Uniform_cell_size', 'Uniform_cell_shape', 'Marginal_Adhesion', 'Single_epithelial_cell_size', 'Bare_Nuclei', 'Bland_Chromatin', 'Normal_Nucleoli', 'Mitoses']
for i,j in enumerate(features):
    plt.subplots_adjust(hspace = 1.0)
    plt.subplot(4, 3, i+1)
    sns.scatterplot("Uniform_cell_size",y=j,data=df)

# %%
#Scatter plot matrix
from pandas.plotting import scatter_matrix
df1=df[features]
scatter_matrix(df1,figsize=(18,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA010E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194E9FB76C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA05E248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194E9EDB488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194E9EBFD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194E9E86C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA58AE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA5BD548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA5C9148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA600308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA668888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA69F908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA6D9A08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA711B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA749C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA782D08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA7BBDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA7F2EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA82CFC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA869148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA8A3248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA8DC308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA914448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA94B588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA98AE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA9BD788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA9F68C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA279B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA2A9088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA2D05C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAB94288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EB174748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA1D5708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA517808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAC2B908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EB175A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA362B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA4FEC08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAA4FD48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA3B9E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA407F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA4A80C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA41F1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EA473248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAA7C388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAAB64C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAAEF5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAB286C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAC61788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAC97888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EACD1988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAD0BAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAD45BC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAD7AC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EADB3DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EADEEEC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAE25FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAE63148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAE9B1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAED32C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAF0C408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAF45508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAF7F608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000194EAFB66C8>]],
#       dtype=object)

# %% [markdown]
# # Building Prediction Model

# %%
#Data Preprocessing for developing model
df.replace('?',-99999,inplace=True)
df.drop(['ID'],axis=1,inplace=True)

# %%
#Creating x and y dataset for training

X=np.array(df.drop(['Class'],1))
Y=np.array(df['Class'])

# %%
#finding Correlation between parametrs 
corr=df.corr(method ='pearson') 
corr
# Out:
#                              Clump_Thickness  Uniform_cell_size  \
# Clump_Thickness                     1.000000           0.644913
# Uniform_cell_size                   0.644913           1.000000
# Uniform_cell_shape                  0.654589           0.906882
# Marginal_Adhesion                   0.486356           0.705582
# Single_epithelial_cell_size         0.521816           0.751799
# Bland_Chromatin                     0.558428           0.755721
# Normal_Nucleoli                     0.535835           0.722865
# Mitoses                             0.350034           0.458693
# Class                               0.716001           0.817904
#
#                              Uniform_cell_shape  Marginal_Adhesion  \
# Clump_Thickness                        0.654589           0.486356
# Uniform_cell_size                      0.906882           0.705582
# Uniform_cell_shape                     1.000000           0.683079
# Marginal_Adhesion                      0.683079           1.000000
# Single_epithelial_cell_size            0.719668           0.599599
# Bland_Chromatin                        0.735948           0.666715
# Normal_Nucleoli                        0.719446           0.603352
# Mitoses                                0.438911           0.417633
# Class                                  0.818934           0.696800
#
#                              Single_epithelial_cell_size  Bland_Chromatin  \
# Clump_Thickness                                 0.521816         0.558428
# Uniform_cell_size                               0.751799         0.755721
# Uniform_cell_shape                              0.719668         0.735948
# Marginal_Adhesion                               0.599599         0.666715
# Single_epithelial_cell_size                     1.000000         0.616102
# Bland_Chromatin                                 0.616102         1.000000
# Normal_Nucleoli                                 0.628881         0.665878
# Mitoses                                         0.479101         0.344169
# Class                                           0.682785         0.756616
#
#                              Normal_Nucleoli   Mitoses     Class
# Clump_Thickness                     0.535835  0.350034  0.716001
# Uniform_cell_size                   0.722865  0.458693  0.817904
# Uniform_cell_shape                  0.719446  0.438911  0.818934
# Marginal_Adhesion                   0.603352  0.417633  0.696800
# Single_epithelial_cell_size         0.628881  0.479101  0.682785
# Bland_Chromatin                     0.665878  0.344169  0.756616
# Normal_Nucleoli                     1.000000  0.428336  0.712244
# Mitoses                             0.428336  1.000000  0.423170
# Class                               0.712244  0.423170  1.000000

# %%
# Correlation Heatmap Using seaborn library
sns.heatmap(corr, xticklabels=corr.columns,yticklabels=corr.columns)

# %% [markdown]
# # Developing Model

# %%
# Splitting Data In Training Set and Test Set 

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.05,random_state = 0)
Y_train=Y_train.astype('int')

# %%
#Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # KNN : K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier2 = KNeighborsClassifier(n_neighbors = 15, metric = 'euclidean', p = 2)
classifier2.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='uniform')

# %%
# Prediction
Y_pred2 = classifier2.predict(X_test)

# %%
# Confusion Matrix for evaluation
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(Y_test, Y_pred2)
confusion_matrix
# Out:
# array([[21,  1],
#        [ 0, 13]], dtype=int64)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred2))
# Out:
# Accuracy: 0.9714285714285714
